# %% [markdown]
# ##### Proyecto 2 teoria de la simulacion
# Josue Salomon Landa 20211001600 :3
#
# ![Hornet](https://images.steamusercontent.com/ugc/1709665624025799474/1D03582C0386590AE8EB073E534CAF0A7A267250/?imw=128&imh=128&ima=fit&impolicy=Letterbox&imcolor=%23000000&letterbox=true)

# %% [markdown]
# #### Importacion de librerias

# %%
import pandas as pd
import numpy as np
import simpy
import random

# %% [markdown]
# #### Creacionde clases para la simulacion

# %%
class Mesa:
    def __init__(self, env, id, num_sillas):
        self.env = env
        self.id = id
        self.num_sillas = simpy.Container(env, init=num_sillas, capacity=num_sillas)

# %%
class Plato:
    def __init__(self, nombre, tiempo_cocina, tiempo_comida):
        self.nombre = nombre
        self.tiempo_cocina = tiempo_cocina
        self.tiempo_comida = tiempo_comida

# %%
class Restaurante:
    def __init__(self, env, mesas, num_meseros, num_chefs, platos):
        self.env = env
        self.mesas = mesas
        self.meseros = simpy.Resource(env, capacity=num_meseros)
        self.chefs = simpy.Resource(env, capacity=num_chefs)
        self.platos = platos

# %%
class Cliente:
    def __init__(self, env, id, mesa, restaurante):
        self.env = env
        self.id = id
        self.mesa: Mesa = mesa
        self.restaurante: Restaurante = restaurante
        self.eventos = pd.DataFrame()
        self.grupo_size = random.randint(2, 4) 
        self.alcanzo_disponibilidad = False
        self.plato = None 
        self.tolerancia_chef = random.randint(5, 15)  
        self.env.process(self.start())

    def start(self):
        ### Llega al restaurante
        print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} llegó al restaurante")
        self.eventos = pd.concat([self.eventos, pd.DataFrame({
            "id": [self.id], "evento": ["LLEGO"], "time": [self.env.now]
        })])

        ###Primer evento con decision, ver si hay sillas disponibles
        if self.mesa.num_sillas.level >= self.grupo_size:  
            yield self.mesa.num_sillas.get(self.grupo_size)
            ##hay silla
            print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} se sienta en mesa {self.mesa.id} con {self.grupo_size} personas")
        else:
            ###No hay sillas
            print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} se fue porque no hay suficientes sillas")
            self.eventos = pd.concat([self.eventos, pd.DataFrame({
                "id": [self.id], "evento": ["SIN SILLA"], "time": [self.env.now]
            })])
            return

        tiempo_esperando_mesero = self.env.now
        self.eventos = pd.concat([self.eventos, pd.DataFrame({
                "id": [self.id], "evento": ["ESPERANDO_MESERO"], "time": [self.env.now]
            })])

        with self.restaurante.meseros.request() as req_mesero:
            yield req_mesero
            tiempo_espera = self.env.now - tiempo_esperando_mesero
            print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} está siendo atendido por el mesero después de esperar {tiempo_espera} minutos")
            self.eventos = pd.concat([self.eventos, pd.DataFrame({
                "id": [self.id], "evento": ["ATENDIDO"], "time": [self.env.now]
            })])

            self.plato = random.choice(self.restaurante.platos)
            print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} pidió '{self.plato.nombre}' con tolerancia de {self.tolerancia_chef} minutos")

            with self.restaurante.chefs.request() as req_chef:
                resultado = yield req_chef | self.env.timeout(self.tolerancia_chef)

                if req_chef in resultado:
                    print(f"🕒 Tiempo: {self.env.now} → Chef comenzó a cocinar para Cliente {self.id}")
                    yield self.env.timeout(self.plato.tiempo_cocina)
                    print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} recibió su comida y empezó a comer '{self.plato.nombre}'")

                    # Comer
                    yield self.env.timeout(self.plato.tiempo_comida)
                    print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} terminó de comer y se fue")

                    self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id], "evento": ["TERMINO COMIDA"], "time": [self.env.now]
                    })])
                else:
                    print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} se fue porque el chef tardó demasiado")
                    self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id], "evento": ["SE FUE POR CHEF"], "time": [self.env.now]
                    })])

        yield self.mesa.num_sillas.put(self.grupo_size)

# %%
class Simulacion:
    def __init__(self, env, mesas_settings, num_meseros, num_chefs, platos_disponibles):
        self.env = env
        self.mesas = [Mesa(env, m["id"], m["num_sillas"]) for m in mesas_settings]
        self.restaurante = Restaurante(env, self.mesas, num_meseros, num_chefs, platos_disponibles)
        self.clientes = []
        self.env.process(self.start())

    def start(self):
        while True:
            yield self.env.timeout(random.randint(1, 4))
            
            mesa_disponible = None
            for mesa in self.mesas:
                if mesa.num_sillas.level >= 2: 
                    mesa_disponible = mesa
                    break
            
            if mesa_disponible: 
                cliente = Cliente(
                    self.env,
                    len(self.clientes) + 1,
                    mesa_disponible,  
                    self.restaurante
                )
                self.clientes.append(cliente)
            else:
                print(f"🕒 Tiempo: {self.env.now} → No hay mesas disponibles para nuevos clientes.")

# %%
env = simpy.Environment()

mesas_settings = [
    {"id": 1, "num_sillas": 4},
    {"id": 2, "num_sillas": 4},
    {"id": 3, "num_sillas": 6}
]

platos_disponibles = [
    Plato("Spaghetti", tiempo_cocina=7, tiempo_comida=6),
    Plato("Pizza", tiempo_cocina=10, tiempo_comida=8),
    Plato("Hamburguesa", tiempo_cocina=5, tiempo_comida=4),
    Plato("Ensalada", tiempo_cocina=3, tiempo_comida=9)
]

simulacion = Simulacion(
    env,
    mesas_settings,
    num_meseros=4,
    num_chefs=2,
    platos_disponibles=platos_disponibles
)
random.seed=45
env.run(until=60*5)
# Out:
# 🕒 Tiempo: 4 → Cliente 1 llegó al restaurante
# 🕒 Tiempo: 4 → Cliente 1 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 4 → Cliente 1 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 4 → Cliente 1 pidió 'Ensalada' con tolerancia de 8 minutos
# 🕒 Tiempo: 4 → Chef comenzó a cocinar para Cliente 1
# 🕒 Tiempo: 6 → Cliente 2 llegó al restaurante
# 🕒 Tiempo: 6 → Cliente 2 se sienta en mesa 2 con 4 personas
# 🕒 Tiempo: 6 → Cliente 2 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 6 → Cliente 2 pidió 'Spaghetti' con tolerancia de 15 minutos
# 🕒 Tiempo: 6 → Chef comenzó a cocinar para Cliente 2
# 🕒 Tiempo: 7 → Cliente 1 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 10 → Cliente 3 llegó al restaurante
# 🕒 Tiempo: 10 → Cliente 3 se sienta en mesa 3 con 3 personas
# 🕒 Tiempo: 10 → Cliente 3 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 10 → Cliente 3 pidió 'Spaghetti' con tolerancia de 12 minutos
# 🕒 Tiempo: 12 → Cliente 4 llegó al restaurante
# 🕒 Tiempo: 12 → Cliente 4 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 12 → Cliente 4 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 12 → Cliente 4 pidió 'Ensalada' con tolerancia de 14 minutos
# 🕒 Tiempo: 13 → Cliente 2 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 15 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 16 → Cliente 1 terminó de comer y se fue
# 🕒 Tiempo: 16 → Chef comenzó a cocinar para Cliente 3
# 🕒 Tiempo: 17 → Cliente 5 llegó al restaurante
# 🕒 Tiempo: 17 → Cliente 5 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 17 → Cliente 5 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 17 → Cliente 5 pidió 'Pizza' con tolerancia de 13 minutos
# 🕒 Tiempo: 19 → Cliente 2 terminó de comer y se fue
# 🕒 Tiempo: 19 → Chef comenzó a cocinar para Cliente 4
# 🕒 Tiempo: 20 → Cliente 6 llegó al restaurante
# 🕒 Tiempo: 20 → Cliente 6 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 20 → Cliente 6 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 20 → Cliente 6 pidió 'Hamburguesa' con tolerancia de 12 minutos
# 🕒 Tiempo: 22 → Cliente 4 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 23 → Cliente 3 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 24 → Cliente 7 llegó al restaurante
# 🕒 Tiempo: 24 → Cliente 7 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 26 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 28 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 29 → Cliente 3 terminó de comer y se fue
# 🕒 Tiempo: 29 → Cliente 8 llegó al restaurante
# 🕒 Tiempo: 29 → Cliente 8 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 29 → Cliente 7 está siendo atendido por el mesero después de esperar 5 minutos
# 🕒 Tiempo: 29 → Cliente 7 pidió 'Spaghetti' con tolerancia de 8 minutos
# 🕒 Tiempo: 29 → Chef comenzó a cocinar para Cliente 5
# 🕒 Tiempo: 31 → Cliente 4 terminó de comer y se fue
# 🕒 Tiempo: 31 → Cliente 8 está siendo atendido por el mesero después de esperar 2 minutos
# 🕒 Tiempo: 31 → Cliente 8 pidió 'Spaghetti' con tolerancia de 10 minutos
# 🕒 Tiempo: 31 → Chef comenzó a cocinar para Cliente 6
# 🕒 Tiempo: 33 → Cliente 9 llegó al restaurante
# 🕒 Tiempo: 33 → Cliente 9 se sienta en mesa 3 con 3 personas
# 🕒 Tiempo: 36 → Cliente 6 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 36 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 37 → Cliente 7 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 37 → Cliente 9 está siendo atendido por el mesero después de esperar 4 minutos
# 🕒 Tiempo: 37 → Cliente 9 pidió 'Ensalada' con tolerancia de 7 minutos
# 🕒 Tiempo: 39 → Cliente 5 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 40 → Cliente 6 terminó de comer y se fue
# 🕒 Tiempo: 40 → Cliente 10 llegó al restaurante
# 🕒 Tiempo: 40 → Cliente 10 se sienta en mesa 2 con 4 personas
# 🕒 Tiempo: 40 → Cliente 10 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 40 → Cliente 10 pidió 'Hamburguesa' con tolerancia de 7 minutos
# 🕒 Tiempo: 40 → Chef comenzó a cocinar para Cliente 8
# 🕒 Tiempo: 41 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 44 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 44 → Cliente 9 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 47 → Cliente 5 terminó de comer y se fue
# 🕒 Tiempo: 47 → Cliente 8 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 47 → Cliente 10 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 48 → Cliente 11 llegó al restaurante
# 🕒 Tiempo: 48 → Cliente 11 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 48 → Cliente 11 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 48 → Cliente 11 pidió 'Ensalada' con tolerancia de 7 minutos
# 🕒 Tiempo: 48 → Chef comenzó a cocinar para Cliente 11
# 🕒 Tiempo: 49 → Cliente 12 llegó al restaurante
# 🕒 Tiempo: 49 → Cliente 12 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 49 → Cliente 12 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 49 → Cliente 12 pidió 'Hamburguesa' con tolerancia de 11 minutos
# 🕒 Tiempo: 51 → Cliente 11 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 51 → Cliente 13 llegó al restaurante
# 🕒 Tiempo: 51 → Cliente 13 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 51 → Cliente 13 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 51 → Cliente 13 pidió 'Ensalada' con tolerancia de 7 minutos
# 🕒 Tiempo: 53 → Cliente 8 terminó de comer y se fue
# 🕒 Tiempo: 53 → Chef comenzó a cocinar para Cliente 12
# 🕒 Tiempo: 55 → Cliente 14 llegó al restaurante
# 🕒 Tiempo: 55 → Cliente 14 se sienta en mesa 3 con 4 personas
# 🕒 Tiempo: 55 → Cliente 14 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 55 → Cliente 14 pidió 'Spaghetti' con tolerancia de 8 minutos
# 🕒 Tiempo: 58 → Cliente 12 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 58 → Cliente 13 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 59 → Cliente 15 llegó al restaurante
# 🕒 Tiempo: 59 → Cliente 15 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 60 → Cliente 11 terminó de comer y se fue
# 🕒 Tiempo: 60 → Cliente 16 llegó al restaurante
# 🕒 Tiempo: 60 → Cliente 16 se sienta en mesa 1 con 4 personas
# 🕒 Tiempo: 60 → Cliente 16 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 60 → Cliente 16 pidió 'Spaghetti' con tolerancia de 11 minutos
# 🕒 Tiempo: 60 → Chef comenzó a cocinar para Cliente 14
# 🕒 Tiempo: 62 → Cliente 12 terminó de comer y se fue
# 🕒 Tiempo: 62 → Chef comenzó a cocinar para Cliente 16
# 🕒 Tiempo: 63 → Cliente 17 llegó al restaurante
# 🕒 Tiempo: 63 → Cliente 17 se sienta en mesa 2 con 3 personas
# 🕒 Tiempo: 63 → Cliente 17 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 63 → Cliente 17 pidió 'Ensalada' con tolerancia de 6 minutos
# 🕒 Tiempo: 65 → Cliente 18 llegó al restaurante
# 🕒 Tiempo: 65 → Cliente 18 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 66 → Cliente 19 llegó al restaurante
# 🕒 Tiempo: 66 → Cliente 19 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 66 → Cliente 19 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 66 → Cliente 19 pidió 'Hamburguesa' con tolerancia de 5 minutos
# 🕒 Tiempo: 67 → Cliente 14 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 69 → Cliente 16 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 69 → Cliente 17 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 70 → Cliente 20 llegó al restaurante
# 🕒 Tiempo: 70 → Cliente 20 se sienta en mesa 2 con 3 personas
# 🕒 Tiempo: 70 → Cliente 20 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 70 → Cliente 20 pidió 'Hamburguesa' con tolerancia de 9 minutos
# 🕒 Tiempo: 71 → Cliente 19 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 73 → Cliente 14 terminó de comer y se fue
# 🕒 Tiempo: 73 → Cliente 21 llegó al restaurante
# 🕒 Tiempo: 73 → Cliente 21 se sienta en mesa 3 con 3 personas
# 🕒 Tiempo: 73 → Cliente 21 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 73 → Cliente 21 pidió 'Hamburguesa' con tolerancia de 5 minutos
# 🕒 Tiempo: 73 → Chef comenzó a cocinar para Cliente 20
# 🕒 Tiempo: 74 → Cliente 22 llegó al restaurante
# 🕒 Tiempo: 74 → Cliente 22 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 74 → Cliente 22 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 74 → Cliente 22 pidió 'Ensalada' con tolerancia de 14 minutos
# 🕒 Tiempo: 75 → Cliente 16 terminó de comer y se fue
# 🕒 Tiempo: 75 → Chef comenzó a cocinar para Cliente 21
# 🕒 Tiempo: 77 → Cliente 23 llegó al restaurante
# 🕒 Tiempo: 77 → Cliente 23 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 77 → Cliente 23 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 77 → Cliente 23 pidió 'Spaghetti' con tolerancia de 5 minutos
# 🕒 Tiempo: 78 → Cliente 20 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 80 → Cliente 21 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 81 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 82 → Cliente 20 terminó de comer y se fue
# 🕒 Tiempo: 82 → Cliente 23 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 82 → Chef comenzó a cocinar para Cliente 22
# 🕒 Tiempo: 83 → Cliente 24 llegó al restaurante
# 🕒 Tiempo: 83 → Cliente 24 se sienta en mesa 1 con 4 personas
# 🕒 Tiempo: 83 → Cliente 24 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 83 → Cliente 24 pidió 'Pizza' con tolerancia de 15 minutos
# 🕒 Tiempo: 84 → Cliente 21 terminó de comer y se fue
# 🕒 Tiempo: 84 → Cliente 25 llegó al restaurante
# 🕒 Tiempo: 84 → Cliente 25 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 84 → Cliente 25 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 84 → Cliente 25 pidió 'Hamburguesa' con tolerancia de 10 minutos
# 🕒 Tiempo: 84 → Chef comenzó a cocinar para Cliente 24
# 🕒 Tiempo: 85 → Cliente 22 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 86 → Cliente 26 llegó al restaurante
# 🕒 Tiempo: 86 → Cliente 26 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 87 → Cliente 27 llegó al restaurante
# 🕒 Tiempo: 87 → Cliente 27 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 87 → Cliente 27 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 87 → Cliente 27 pidió 'Ensalada' con tolerancia de 11 minutos
# 🕒 Tiempo: 90 → Cliente 28 llegó al restaurante
# 🕒 Tiempo: 90 → Cliente 28 se sienta en mesa 3 con 3 personas
# 🕒 Tiempo: 94 → Cliente 24 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 94 → Cliente 22 terminó de comer y se fue
# 🕒 Tiempo: 94 → Cliente 29 llegó al restaurante
# 🕒 Tiempo: 94 → Cliente 25 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 94 → Cliente 29 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 94 → Cliente 28 está siendo atendido por el mesero después de esperar 4 minutos
# 🕒 Tiempo: 94 → Cliente 28 pidió 'Spaghetti' con tolerancia de 5 minutos
# 🕒 Tiempo: 94 → Cliente 29 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 94 → Cliente 29 pidió 'Ensalada' con tolerancia de 15 minutos
# 🕒 Tiempo: 94 → Chef comenzó a cocinar para Cliente 27
# 🕒 Tiempo: 95 → Cliente 30 llegó al restaurante
# 🕒 Tiempo: 95 → Cliente 30 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 96 → Cliente 31 llegó al restaurante
# 🕒 Tiempo: 96 → Cliente 31 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 97 → Cliente 27 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 99 → Cliente 32 llegó al restaurante
# 🕒 Tiempo: 99 → Cliente 32 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 99 → Cliente 28 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 102 → Cliente 24 terminó de comer y se fue
# 🕒 Tiempo: 102 → Cliente 33 llegó al restaurante
# 🕒 Tiempo: 102 → Cliente 33 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 102 → Cliente 33 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 102 → Cliente 33 pidió 'Pizza' con tolerancia de 11 minutos
# 🕒 Tiempo: 102 → Chef comenzó a cocinar para Cliente 29
# 🕒 Tiempo: 105 → Cliente 34 llegó al restaurante
# 🕒 Tiempo: 105 → Cliente 34 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 105 → Cliente 29 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 106 → Cliente 27 terminó de comer y se fue
# 🕒 Tiempo: 106 → Chef comenzó a cocinar para Cliente 33
# 🕒 Tiempo: 107 → Cliente 35 llegó al restaurante
# 🕒 Tiempo: 107 → Cliente 35 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 107 → Cliente 35 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 107 → Cliente 35 pidió 'Spaghetti' con tolerancia de 14 minutos
# 🕒 Tiempo: 110 → Cliente 36 llegó al restaurante
# 🕒 Tiempo: 110 → Cliente 36 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 110 → Cliente 36 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 110 → Cliente 36 pidió 'Spaghetti' con tolerancia de 6 minutos
# 🕒 Tiempo: 114 → Cliente 29 terminó de comer y se fue
# 🕒 Tiempo: 114 → Cliente 37 llegó al restaurante
# 🕒 Tiempo: 114 → Cliente 37 se sienta en mesa 3 con 4 personas
# 🕒 Tiempo: 114 → Cliente 37 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 114 → Cliente 37 pidió 'Hamburguesa' con tolerancia de 9 minutos
# 🕒 Tiempo: 114 → Chef comenzó a cocinar para Cliente 35
# 🕒 Tiempo: 116 → Cliente 33 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 116 → Cliente 36 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 117 → Cliente 38 llegó al restaurante
# 🕒 Tiempo: 117 → Cliente 38 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 117 → Cliente 38 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 117 → Cliente 38 pidió 'Ensalada' con tolerancia de 5 minutos
# 🕒 Tiempo: 120 → Cliente 39 llegó al restaurante
# 🕒 Tiempo: 120 → Cliente 39 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 121 → Cliente 35 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 122 → Cliente 38 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 123 → Cliente 37 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 124 → Cliente 33 terminó de comer y se fue
# 🕒 Tiempo: 124 → Cliente 40 llegó al restaurante
# 🕒 Tiempo: 124 → Cliente 40 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 124 → Cliente 40 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 124 → Cliente 40 pidió 'Spaghetti' con tolerancia de 15 minutos
# 🕒 Tiempo: 124 → Chef comenzó a cocinar para Cliente 40
# 🕒 Tiempo: 126 → Cliente 41 llegó al restaurante
# 🕒 Tiempo: 126 → Cliente 41 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 127 → Cliente 35 terminó de comer y se fue
# 🕒 Tiempo: 128 → Cliente 42 llegó al restaurante
# 🕒 Tiempo: 128 → Cliente 42 se sienta en mesa 2 con 4 personas
# 🕒 Tiempo: 128 → Cliente 42 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 128 → Cliente 42 pidió 'Pizza' con tolerancia de 12 minutos
# 🕒 Tiempo: 128 → Chef comenzó a cocinar para Cliente 42
# 🕒 Tiempo: 131 → Cliente 40 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 131 → Cliente 43 llegó al restaurante
# 🕒 Tiempo: 131 → Cliente 43 se sienta en mesa 3 con 4 personas
# 🕒 Tiempo: 131 → Cliente 43 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 131 → Cliente 43 pidió 'Ensalada' con tolerancia de 10 minutos
# 🕒 Tiempo: 135 → Cliente 44 llegó al restaurante
# 🕒 Tiempo: 135 → Cliente 44 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 136 → Cliente 45 llegó al restaurante
# 🕒 Tiempo: 136 → Cliente 45 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 136 → Cliente 45 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 136 → Cliente 45 pidió 'Spaghetti' con tolerancia de 11 minutos
# 🕒 Tiempo: 137 → Cliente 40 terminó de comer y se fue
# 🕒 Tiempo: 137 → Chef comenzó a cocinar para Cliente 43
# 🕒 Tiempo: 138 → Cliente 42 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 138 → Cliente 46 llegó al restaurante
# 🕒 Tiempo: 138 → Cliente 46 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 138 → Cliente 46 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 138 → Cliente 46 pidió 'Hamburguesa' con tolerancia de 8 minutos
# 🕒 Tiempo: 140 → Cliente 43 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 141 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 143 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 146 → Cliente 42 terminó de comer y se fue
# 🕒 Tiempo: 146 → Cliente 47 llegó al restaurante
# 🕒 Tiempo: 146 → Cliente 46 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 146 → Cliente 47 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 146 → Cliente 47 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 146 → Cliente 47 pidió 'Pizza' con tolerancia de 5 minutos
# 🕒 Tiempo: 146 → Chef comenzó a cocinar para Cliente 45
# 🕒 Tiempo: 149 → Cliente 43 terminó de comer y se fue
# 🕒 Tiempo: 149 → Cliente 48 llegó al restaurante
# 🕒 Tiempo: 149 → Cliente 48 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 149 → Cliente 48 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 149 → Cliente 48 pidió 'Hamburguesa' con tolerancia de 6 minutos
# 🕒 Tiempo: 149 → Chef comenzó a cocinar para Cliente 47
# 🕒 Tiempo: 151 → Cliente 49 llegó al restaurante
# 🕒 Tiempo: 151 → Cliente 49 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 153 → Cliente 45 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 155 → Cliente 50 llegó al restaurante
# 🕒 Tiempo: 155 → Cliente 48 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 155 → Cliente 50 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 155 → Cliente 50 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 155 → Cliente 50 pidió 'Pizza' con tolerancia de 8 minutos
# 🕒 Tiempo: 159 → Cliente 47 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 159 → Cliente 45 terminó de comer y se fue
# 🕒 Tiempo: 159 → Cliente 51 llegó al restaurante
# 🕒 Tiempo: 159 → Cliente 51 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 159 → Chef comenzó a cocinar para Cliente 50
# 🕒 Tiempo: 162 → Cliente 52 llegó al restaurante
# 🕒 Tiempo: 162 → Cliente 52 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 162 → Cliente 52 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 162 → Cliente 52 pidió 'Hamburguesa' con tolerancia de 10 minutos
# 🕒 Tiempo: 165 → Cliente 53 llegó al restaurante
# 🕒 Tiempo: 165 → Cliente 53 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 166 → Cliente 54 llegó al restaurante
# 🕒 Tiempo: 166 → Cliente 54 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 167 → Cliente 47 terminó de comer y se fue
# 🕒 Tiempo: 167 → Chef comenzó a cocinar para Cliente 52
# 🕒 Tiempo: 169 → Cliente 50 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 170 → Cliente 55 llegó al restaurante
# 🕒 Tiempo: 170 → Cliente 55 se sienta en mesa 2 con 3 personas
# 🕒 Tiempo: 170 → Cliente 55 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 170 → Cliente 55 pidió 'Spaghetti' con tolerancia de 11 minutos
# 🕒 Tiempo: 172 → Cliente 52 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 174 → Cliente 56 llegó al restaurante
# 🕒 Tiempo: 174 → Cliente 56 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 174 → Cliente 56 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 174 → Cliente 56 pidió 'Hamburguesa' con tolerancia de 14 minutos
# 🕒 Tiempo: 176 → Cliente 52 terminó de comer y se fue
# 🕒 Tiempo: 176 → Chef comenzó a cocinar para Cliente 55
# 🕒 Tiempo: 177 → Cliente 50 terminó de comer y se fue
# 🕒 Tiempo: 177 → Cliente 57 llegó al restaurante
# 🕒 Tiempo: 177 → Cliente 57 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 177 → Cliente 57 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 177 → Cliente 57 pidió 'Hamburguesa' con tolerancia de 6 minutos
# 🕒 Tiempo: 177 → Chef comenzó a cocinar para Cliente 56
# 🕒 Tiempo: 179 → Cliente 58 llegó al restaurante
# 🕒 Tiempo: 179 → Cliente 58 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 181 → Cliente 59 llegó al restaurante
# 🕒 Tiempo: 181 → Cliente 59 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 182 → Cliente 56 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 183 → Cliente 55 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 183 → Cliente 57 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 185 → Cliente 60 llegó al restaurante
# 🕒 Tiempo: 185 → Cliente 60 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 185 → Cliente 60 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 185 → Cliente 60 pidió 'Ensalada' con tolerancia de 7 minutos
# 🕒 Tiempo: 186 → Cliente 56 terminó de comer y se fue
# 🕒 Tiempo: 186 → Chef comenzó a cocinar para Cliente 60
# 🕒 Tiempo: 189 → Cliente 55 terminó de comer y se fue
# 🕒 Tiempo: 189 → Cliente 61 llegó al restaurante
# 🕒 Tiempo: 189 → Cliente 61 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 189 → Cliente 60 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 190 → Cliente 62 llegó al restaurante
# 🕒 Tiempo: 190 → Cliente 62 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 194 → Cliente 63 llegó al restaurante
# 🕒 Tiempo: 194 → Cliente 63 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 194 → Cliente 63 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 194 → Cliente 63 pidió 'Pizza' con tolerancia de 11 minutos
# 🕒 Tiempo: 194 → Chef comenzó a cocinar para Cliente 63
# 🕒 Tiempo: 196 → Cliente 64 llegó al restaurante
# 🕒 Tiempo: 196 → Cliente 64 se sienta en mesa 2 con 3 personas
# 🕒 Tiempo: 196 → Cliente 64 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 196 → Cliente 64 pidió 'Ensalada' con tolerancia de 13 minutos
# 🕒 Tiempo: 197 → Cliente 65 llegó al restaurante
# 🕒 Tiempo: 197 → Cliente 65 se sienta en mesa 3 con 4 personas
# 🕒 Tiempo: 197 → Cliente 65 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 197 → Cliente 65 pidió 'Ensalada' con tolerancia de 11 minutos
# 🕒 Tiempo: 198 → Cliente 60 terminó de comer y se fue
# 🕒 Tiempo: 198 → Chef comenzó a cocinar para Cliente 64
# 🕒 Tiempo: 200 → Cliente 66 llegó al restaurante
# 🕒 Tiempo: 200 → Cliente 66 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 201 → Cliente 64 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 204 → Cliente 63 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 204 → Cliente 67 llegó al restaurante
# 🕒 Tiempo: 204 → Cliente 67 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 205 → Cliente 68 llegó al restaurante
# 🕒 Tiempo: 205 → Cliente 68 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 208 → Cliente 69 llegó al restaurante
# 🕒 Tiempo: 208 → Cliente 65 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 208 → Cliente 69 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 208 → Cliente 69 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 208 → Cliente 69 pidió 'Spaghetti' con tolerancia de 6 minutos
# 🕒 Tiempo: 209 → Cliente 70 llegó al restaurante
# 🕒 Tiempo: 209 → Cliente 70 se sienta en mesa 3 con 4 personas
# 🕒 Tiempo: 209 → Cliente 70 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 209 → Cliente 70 pidió 'Pizza' con tolerancia de 8 minutos
# 🕒 Tiempo: 210 → Cliente 64 terminó de comer y se fue
# 🕒 Tiempo: 210 → Chef comenzó a cocinar para Cliente 69
# 🕒 Tiempo: 211 → Cliente 71 llegó al restaurante
# 🕒 Tiempo: 211 → Cliente 71 se sienta en mesa 2 con 4 personas
# 🕒 Tiempo: 211 → Cliente 71 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 211 → Cliente 71 pidió 'Pizza' con tolerancia de 7 minutos
# 🕒 Tiempo: 212 → Cliente 63 terminó de comer y se fue
# 🕒 Tiempo: 212 → Cliente 72 llegó al restaurante
# 🕒 Tiempo: 212 → Cliente 72 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 212 → Cliente 72 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 212 → Cliente 72 pidió 'Ensalada' con tolerancia de 11 minutos
# 🕒 Tiempo: 212 → Chef comenzó a cocinar para Cliente 70
# 🕒 Tiempo: 213 → Cliente 73 llegó al restaurante
# 🕒 Tiempo: 213 → Cliente 73 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 215 → Cliente 74 llegó al restaurante
# 🕒 Tiempo: 215 → Cliente 74 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 217 → Cliente 69 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 218 → Cliente 71 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 219 → Cliente 75 llegó al restaurante
# 🕒 Tiempo: 219 → Cliente 75 se sienta en mesa 2 con 3 personas
# 🕒 Tiempo: 219 → Cliente 75 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 219 → Cliente 75 pidió 'Pizza' con tolerancia de 7 minutos
# 🕒 Tiempo: 220 → Cliente 76 llegó al restaurante
# 🕒 Tiempo: 220 → Cliente 76 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 221 → Cliente 77 llegó al restaurante
# 🕒 Tiempo: 221 → Cliente 77 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 222 → Cliente 70 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 222 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 223 → Cliente 69 terminó de comer y se fue
# 🕒 Tiempo: 223 → Cliente 72 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 223 → Cliente 77 está siendo atendido por el mesero después de esperar 2 minutos
# 🕒 Tiempo: 223 → Cliente 77 pidió 'Pizza' con tolerancia de 6 minutos
# 🕒 Tiempo: 223 → Chef comenzó a cocinar para Cliente 75
# 🕒 Tiempo: 224 → Cliente 78 llegó al restaurante
# 🕒 Tiempo: 224 → Cliente 78 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 224 → Cliente 78 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 224 → Cliente 78 pidió 'Pizza' con tolerancia de 15 minutos
# 🕒 Tiempo: 226 → Cliente 79 llegó al restaurante
# 🕒 Tiempo: 226 → Cliente 79 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 227 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 228 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 229 → Cliente 77 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 229 → Cliente 79 está siendo atendido por el mesero después de esperar 3 minutos
# 🕒 Tiempo: 229 → Cliente 79 pidió 'Hamburguesa' con tolerancia de 10 minutos
# 🕒 Tiempo: 230 → Cliente 70 terminó de comer y se fue
# 🕒 Tiempo: 230 → Chef comenzó a cocinar para Cliente 78
# 🕒 Tiempo: 232 → Cliente 80 llegó al restaurante
# 🕒 Tiempo: 232 → Cliente 80 se sienta en mesa 3 con 4 personas
# 🕒 Tiempo: 232 → Cliente 80 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 232 → Cliente 80 pidió 'Pizza' con tolerancia de 8 minutos
# 🕒 Tiempo: 233 → Cliente 75 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 236 → Cliente 81 llegó al restaurante
# 🕒 Tiempo: 236 → Cliente 81 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 239 → Cliente 79 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 240 → Cliente 78 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 240 → Cliente 82 llegó al restaurante
# 🕒 Tiempo: 240 → Cliente 82 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 240 → Cliente 80 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 241 → Cliente 75 terminó de comer y se fue
# 🕒 Tiempo: 244 → Cliente 83 llegó al restaurante
# 🕒 Tiempo: 244 → Cliente 83 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 246 → Cliente 84 llegó al restaurante
# 🕒 Tiempo: 246 → Cliente 84 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 248 → Cliente 78 terminó de comer y se fue
# 🕒 Tiempo: 248 → Cliente 85 llegó al restaurante
# 🕒 Tiempo: 248 → Cliente 85 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 248 → Cliente 85 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 248 → Cliente 85 pidió 'Ensalada' con tolerancia de 6 minutos
# 🕒 Tiempo: 248 → Chef comenzó a cocinar para Cliente 85
# 🕒 Tiempo: 249 → Cliente 86 llegó al restaurante
# 🕒 Tiempo: 249 → Cliente 86 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 251 → Cliente 85 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 253 → Cliente 87 llegó al restaurante
# 🕒 Tiempo: 253 → Cliente 87 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 254 → Cliente 88 llegó al restaurante
# 🕒 Tiempo: 254 → Cliente 88 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 258 → Cliente 89 llegó al restaurante
# 🕒 Tiempo: 258 → Cliente 89 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 258 → Cliente 89 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 258 → Cliente 89 pidió 'Spaghetti' con tolerancia de 15 minutos
# 🕒 Tiempo: 258 → Chef comenzó a cocinar para Cliente 89
# 🕒 Tiempo: 259 → Cliente 90 llegó al restaurante
# 🕒 Tiempo: 259 → Cliente 90 se sienta en mesa 2 con 3 personas
# 🕒 Tiempo: 259 → Cliente 90 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 259 → Cliente 90 pidió 'Ensalada' con tolerancia de 10 minutos
# 🕒 Tiempo: 260 → Cliente 85 terminó de comer y se fue
# 🕒 Tiempo: 260 → Chef comenzó a cocinar para Cliente 90
# 🕒 Tiempo: 262 → Cliente 91 llegó al restaurante
# 🕒 Tiempo: 262 → Cliente 91 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 263 → Cliente 90 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 263 → Cliente 92 llegó al restaurante
# 🕒 Tiempo: 263 → Cliente 92 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 265 → Cliente 89 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 266 → Cliente 93 llegó al restaurante
# 🕒 Tiempo: 266 → Cliente 93 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 266 → Cliente 93 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 266 → Cliente 93 pidió 'Spaghetti' con tolerancia de 9 minutos
# 🕒 Tiempo: 268 → Cliente 94 llegó al restaurante
# 🕒 Tiempo: 268 → Cliente 94 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 268 → Cliente 94 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 268 → Cliente 94 pidió 'Spaghetti' con tolerancia de 8 minutos
# 🕒 Tiempo: 271 → Cliente 89 terminó de comer y se fue
# 🕒 Tiempo: 271 → Chef comenzó a cocinar para Cliente 93
# 🕒 Tiempo: 272 → Cliente 90 terminó de comer y se fue
# 🕒 Tiempo: 272 → Cliente 95 llegó al restaurante
# 🕒 Tiempo: 272 → Cliente 95 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 272 → Cliente 95 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 272 → Cliente 95 pidió 'Hamburguesa' con tolerancia de 9 minutos
# 🕒 Tiempo: 272 → Chef comenzó a cocinar para Cliente 94
# 🕒 Tiempo: 276 → Cliente 96 llegó al restaurante
# 🕒 Tiempo: 276 → Cliente 96 se sienta en mesa 2 con 3 personas
# 🕒 Tiempo: 276 → Cliente 96 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 276 → Cliente 96 pidió 'Pizza' con tolerancia de 14 minutos
# 🕒 Tiempo: 278 → Cliente 93 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 279 → Cliente 94 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 280 → Cliente 97 llegó al restaurante
# 🕒 Tiempo: 280 → Cliente 97 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 281 → Cliente 95 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 281 → Cliente 97 está siendo atendido por el mesero después de esperar 1 minutos
# 🕒 Tiempo: 281 → Cliente 97 pidió 'Pizza' con tolerancia de 7 minutos
# 🕒 Tiempo: 283 → Cliente 98 llegó al restaurante
# 🕒 Tiempo: 283 → Cliente 98 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 284 → Cliente 93 terminó de comer y se fue
# 🕒 Tiempo: 284 → Chef comenzó a cocinar para Cliente 96
# 🕒 Tiempo: 285 → Cliente 94 terminó de comer y se fue
# 🕒 Tiempo: 285 → Chef comenzó a cocinar para Cliente 97
# 🕒 Tiempo: 287 → Cliente 99 llegó al restaurante
# 🕒 Tiempo: 287 → Cliente 99 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 287 → Cliente 99 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 287 → Cliente 99 pidió 'Hamburguesa' con tolerancia de 7 minutos
# 🕒 Tiempo: 288 → Cliente 100 llegó al restaurante
# 🕒 Tiempo: 288 → Cliente 100 se sienta en mesa 3 con 3 personas
# 🕒 Tiempo: 288 → Cliente 100 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 288 → Cliente 100 pidió 'Ensalada' con tolerancia de 6 minutos
# 🕒 Tiempo: 290 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 291 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 293 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 294 → Cliente 96 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 294 → Cliente 99 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 294 → Cliente 100 se fue porque el chef tardó demasiado
# 🕒 Tiempo: 295 → Cliente 97 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 295 → Cliente 101 llegó al restaurante
# 🕒 Tiempo: 295 → Cliente 101 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 295 → Cliente 101 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 295 → Cliente 101 pidió 'Pizza' con tolerancia de 7 minutos
# 🕒 Tiempo: 296 → Cliente 102 llegó al restaurante
# 🕒 Tiempo: 296 → Cliente 102 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 296 → Cliente 102 está siendo atendido por el mesero después de esperar 0 minutos
# 🕒 Tiempo: 296 → Cliente 102 pidió 'Hamburguesa' con tolerancia de 12 minutos

# %%
lista_clientes = []

for c in simulacion.clientes:
    lista_clientes.append({
        "id": c.id,
        "grupo_size": c.grupo_size,
        "mesa_id": c.mesa.id if hasattr(c, 'mesa') and c.mesa else None, 
        "plato_seleccionado": c.plato.nombre if c.plato else None, 
        "tiempo_comida": c.plato.tiempo_comida if c.plato else None,  
        "tolerancia_espera_chef": c.tolerancia_chef 
    })

df_clientes = pd.DataFrame(lista_clientes)

# %%
df_clientes
# Out:
#       id  grupo_size  mesa_id plato_seleccionado  tiempo_comida  \
# 0      1           3        1           Ensalada            9.0
# 1      2           4        2          Spaghetti            6.0
# 2      3           3        3          Spaghetti            6.0
# 3      4           2        3           Ensalada            9.0
# 4      5           3        1              Pizza            8.0
# ..   ...         ...      ...                ...            ...
# 97    98           3        1               None            NaN
# 98    99           3        1        Hamburguesa            4.0
# 99   100           3        3           Ensalada            9.0
# 100  101           2        1              Pizza            8.0
# 101  102           2        1        Hamburguesa            4.0
#
#      tolerancia_espera_chef
# 0                         8
# 1                        15
# 2                        12
# 3                        14
# 4                        13
# ..                      ...
# 97                       12
# 98                        7
# 99                        6
# 100                       7
# 101                      12
#
# [102 rows x 6 columns]

# %%
lista_eventos = []

for c in simulacion.clientes:
    lista_eventos.append(c.eventos)

df_eventos = pd.concat(lista_eventos).reset_index(drop=True)

# %%
df_eventos
# Out:
#       id            evento  time
# 0      1             LLEGO     4
# 1      1  ESPERANDO_MESERO     4
# 2      1          ATENDIDO     4
# 3      1    TERMINO COMIDA    16
# 4      2             LLEGO     6
# ..   ...               ...   ...
# 331  101  ESPERANDO_MESERO   295
# 332  101          ATENDIDO   295
# 333  102             LLEGO   296
# 334  102  ESPERANDO_MESERO   296
# 335  102          ATENDIDO   296
#
# [336 rows x 3 columns]

# %% [markdown]
# #### Preguntas

# %% [markdown]
# 1) ¿Cuánto tiempo de espera tuvieron los clientes antes de sentarse en una mesa?

# %%
llegadas = df_eventos[df_eventos['evento'] == 'LLEGO'].set_index('id')
atendidos = df_eventos[df_eventos['evento'] == 'ATENDIDO'].set_index('id')

tiempos_espera = pd.DataFrame()
tiempos_espera['tiempo_llegada'] = llegadas['time']
tiempos_espera['tiempo_atendido'] = atendidos['time']
tiempos_espera['espera_para_sentarse'] = tiempos_espera['tiempo_atendido'] - tiempos_espera['tiempo_llegada']

promedio_espera = tiempos_espera['espera_para_sentarse'].mean()
max_espera = tiempos_espera['espera_para_sentarse'].max()
min_espera = tiempos_espera['espera_para_sentarse'].min()

print(f"Tiempo promedio de espera para sentarse: {promedio_espera:.2f} minutos")
print(f"Tiempo máximo de espera: {max_espera:.2f} minutos")
print(f"Tiempo mínimo de espera: {min_espera:.2f} minutos")
# Out:
# Tiempo promedio de espera para sentarse: 0.31 minutos
# Tiempo máximo de espera: 5.00 minutos
# Tiempo mínimo de espera: 0.00 minutos

# %% [markdown]
# 2.¿Cuál es el tamaño de grupo más común entre los clientes y qué porcentaje del total representan?

# %%
tamaños_grupos = df_clientes['grupo_size'].value_counts()


tamaño_comun = tamaños_grupos.idxmax()
cantidad = tamaños_grupos.max()


total_clientes = len(df_clientes)
porcentaje = (cantidad / total_clientes) * 100

print(f"El tamaño de grupo más común fue: {tamaño_comun} personas")
print(f"Hubo {cantidad} grupos de este tamaño ({porcentaje:.1f}% del total)")
# Out:
# El tamaño de grupo más común fue: 3 personas
# Hubo 38 grupos de este tamaño (37.3% del total)

# %% [markdown]
# 3) ¿Cuántos clientes completaron su comida

# %%
terminaron = df_eventos[df_eventos['evento'] == 'TERMINO COMIDA']['id'].nunique()
se_fueron_chef = df_eventos[df_eventos['evento'] == 'SE FUE POR CHEF']['id'].nunique()
total_clientes = len(df_clientes)

porcentaje_terminaron = (terminaron / total_clientes) * 100
porcentaje_se_fueron = (se_fueron_chef / total_clientes) * 100

print(f"Clientes que completaron su comida: {terminaron} ({porcentaje_terminaron:.1f}%)")
print(f"Clientes que se fueron por demoras del chef: {se_fueron_chef} ({porcentaje_se_fueron:.1f}%)")
print(f"Total de clientes: {total_clientes}")


tolerancia_terminaron = df_clientes[df_clientes['id'].isin(
    df_eventos[df_eventos['evento'] == 'TERMINO COMIDA']['id'])]['tolerancia_espera_chef'].mean()
tolerancia_se_fueron = df_clientes[df_clientes['id'].isin(
    df_eventos[df_eventos['evento'] == 'SE FUE POR CHEF']['id'])]['tolerancia_espera_chef'].mean()

print(f"\nTolerancia promedio de quienes terminaron: {tolerancia_terminaron:.2f} minutos")
print(f"Tolerancia promedio de quienes se fueron: {tolerancia_se_fueron:.2f} minutos")
# Out:
# Clientes que completaron su comida: 40 (39.2%)
# Clientes que se fueron por demoras del chef: 24 (23.5%)
# Total de clientes: 102
#
# Tolerancia promedio de quienes terminaron: 10.65 minutos
# Tolerancia promedio de quienes se fueron: 7.29 minutos

# %% [markdown]
# 4) ¿En promedio, desde que llegó hasta que se fue, cuánto tiempo invirtió cada cliente en el restaurante?

# %%
tiempos = []

for id in df_eventos['id'].unique():
    eventos = df_eventos[df_eventos['id'] == id]
    
    if 'LLEGO' in eventos['evento'].values:
        inicio = eventos[eventos['evento'] == 'LLEGO']['time'].values[0]
        
        for fin_evento in ['TERMINO COMIDA', 'SE FUE POR CHEF', 'SIN SILLA']:
            if fin_evento in eventos['evento'].values:
                fin = eventos[eventos['evento'] == fin_evento]['time'].values[0]
                tiempos.append(fin - inicio)
                break

promedio = sum(tiempos) / len(tiempos) if tiempos else 0
print(f"Tiempo promedio de estancia: {promedio:.2f} minutos")
# Out:
# Tiempo promedio de estancia: 9.09 minutos

# %% [markdown]
# 5) ¿Cuántos clientes no alcanzaron a ser atendidos?

# %%
total_clientes = len(df_clientes)
sin_silla = df_eventos[df_eventos['evento'] == 'SIN SILLA']['id'].nunique()
sin_chef = df_eventos[df_eventos['evento'] == 'SE FUE POR CHEF']['id'].nunique()
total_no_atendidos = sin_silla + sin_chef

print(f"Total de clientes durante las 8 horas: {total_clientes}")
print(f"Clientes que no encontraron mesa disponible: {sin_silla} ({sin_silla/total_clientes*100:.2f}%)")
print(f"Clientes que se fueron por espera del chef: {sin_chef} ({sin_chef/total_clientes*100:.2f}%)")
print(f"Total clientes no atendidos completamente: {total_no_atendidos} ({total_no_atendidos/total_clientes*100:.2f}%)")

# Contar clientes que completaron su comida
completaron = df_eventos[df_eventos['evento'] == 'TERMINO COMIDA']['id'].nunique()
print(f"Clientes que completaron su comida: {completaron} ({completaron/total_clientes*100:.2f}%)")
# Out:
# Total de clientes durante las 8 horas: 102
# Clientes que no encontraron mesa disponible: 34 (33.33%)
# Clientes que se fueron por espera del chef: 24 (23.53%)
# Total clientes no atendidos completamente: 58 (56.86%)
# Clientes que completaron su comida: 40 (39.22%)
