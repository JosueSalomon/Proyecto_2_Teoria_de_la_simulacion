# %% [markdown]
# ##### Proyecto 2 teoria de la simulacion
# Josue Salomon Landa 20211001600 :3
#
# ![Hornet](https://images.steamusercontent.com/ugc/1709665624025799474/1D03582C0386590AE8EB073E534CAF0A7A267250/?imw=128&imh=128&ima=fit&impolicy=Letterbox&imcolor=%23000000&letterbox=true)

# %% [markdown]
# #### Importacion de librerias

# %%
import pandas as pd
import numpy as np
import simpy
import random

# %% [markdown]
# #### Creacionde clases para la simulacion

# %%
class Mesa:
    def __init__(self, env, id, num_sillas):
        self.env = env
        self.id = id
        self.num_sillas = simpy.Container(env, init=num_sillas, capacity=num_sillas)

# %%
class Plato:
    def __init__(self, nombre, tiempo_cocina, tiempo_comida):
        self.nombre = nombre
        self.tiempo_cocina = tiempo_cocina
        self.tiempo_comida = tiempo_comida

# %%
class Restaurante:
    def __init__(self, env, mesas, num_meseros, num_chefs, platos):
        self.env = env
        self.mesas = mesas
        self.meseros = simpy.Resource(env, capacity=num_meseros)
        self.chefs = simpy.Resource(env, capacity=num_chefs)
        self.platos = platos

# %%
class Cliente:
    def __init__(self, env, id, mesa, restaurante):
        self.env = env
        self.id = id
        self.mesa: Mesa = mesa
        self.restaurante: Restaurante = restaurante
        self.eventos = pd.DataFrame()
        self.grupo_size = random.randint(2, 4) 
        self.alcanzo_disponibilidad = False
        self.plato = None 
        self.tolerancia_chef = random.randint(5, 15)  
        self.env.process(self.start())

    def start(self):
        print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} llegó al restaurante")
        self.eventos = pd.concat([self.eventos, pd.DataFrame({
            "id": [self.id], "evento": ["LLEGO"], "time": [self.env.now]
        })])

        if self.mesa.num_sillas.level >= self.grupo_size:  
            yield self.mesa.num_sillas.get(self.grupo_size)  
            print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} se sienta en mesa {self.mesa.id} con {self.grupo_size} personas")
        else:
            print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} se fue porque no hay suficientes sillas")
            self.eventos = pd.concat([self.eventos, pd.DataFrame({
                "id": [self.id], "evento": ["SIN SILLA"], "time": [self.env.now]
            })])
            return

        with self.restaurante.meseros.request() as req_mesero:
            yield req_mesero
            print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} está siendo atendido por el mesero")
            self.eventos = pd.concat([self.eventos, pd.DataFrame({
                "id": [self.id], "evento": ["ATENDIDO"], "time": [self.env.now]
            })])

            self.plato = random.choice(self.restaurante.platos)
            print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} pidió '{self.plato.nombre}' con tolerancia de {self.tolerancia_chef} minutos")

            with self.restaurante.chefs.request() as req_chef:
                resultado = yield req_chef | self.env.timeout(self.tolerancia_chef)

                if req_chef in resultado:
                    print(f"🕒 Tiempo: {self.env.now} → Chef comenzó a cocinar para Cliente {self.id}")
                    yield self.env.timeout(self.plato.tiempo_cocina)
                    print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} recibió su comida y empezó a comer '{self.plato.nombre}'")

                    # Comer
                    yield self.env.timeout(self.plato.tiempo_comida)
                    print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} terminó de comer y se fue")

                    self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id], "evento": ["TERMINO COMIDA"], "time": [self.env.now]
                    })])
                else:
                    print(f"🕒 Tiempo: {self.env.now} → Cliente {self.id} se fue porque el chef tardó demasiado")
                    self.eventos = pd.concat([self.eventos, pd.DataFrame({
                        "id": [self.id], "evento": ["SE FUE POR CHEF"], "time": [self.env.now]
                    })])

        yield self.mesa.num_sillas.put(self.grupo_size)

# %%
class Simulacion:
    def __init__(self, env, mesas_settings, num_meseros, num_chefs, platos_disponibles):
        self.env = env
        self.mesas = [Mesa(env, m["id"], m["num_sillas"]) for m in mesas_settings]
        self.restaurante = Restaurante(env, self.mesas, num_meseros, num_chefs, platos_disponibles)
        self.clientes = []
        self.env.process(self.start())

    def start(self):
        while True:
            yield self.env.timeout(random.randint(1, 4))
            
            mesa_disponible = None
            for mesa in self.mesas:
                if mesa.num_sillas.level >= 2: 
                    mesa_disponible = mesa
                    break
            
            if mesa_disponible: 
                cliente = Cliente(
                    self.env,
                    len(self.clientes) + 1,
                    mesa_disponible,  
                    self.restaurante
                )
                self.clientes.append(cliente)
            else:
                print(f"🕒 Tiempo: {self.env.now} → No hay mesas disponibles para nuevos clientes.")

# %%
env = simpy.Environment()

mesas_settings = [
    {"id": 1, "num_sillas": 4},
    {"id": 2, "num_sillas": 4},
    {"id": 3, "num_sillas": 6}
]

platos_disponibles = [
    Plato("Spaghetti", tiempo_cocina=7, tiempo_comida=6),
    Plato("Pizza", tiempo_cocina=10, tiempo_comida=8),
    Plato("Hamburguesa", tiempo_cocina=5, tiempo_comida=4),
    Plato("Ensalada", tiempo_cocina=3, tiempo_comida=9)
]

simulacion = Simulacion(
    env,
    mesas_settings,
    num_meseros=4,
    num_chefs=4,
    platos_disponibles=platos_disponibles
)
random.seed=45
env.run(until=60*5)
# Out:
# 🕒 Tiempo: 1 → Cliente 1 llegó al restaurante
# 🕒 Tiempo: 1 → Cliente 1 se sienta en mesa 1 con 4 personas
# 🕒 Tiempo: 1 → Cliente 1 está siendo atendido por el mesero
# 🕒 Tiempo: 1 → Cliente 1 pidió 'Pizza' con tolerancia de 14 minutos
# 🕒 Tiempo: 1 → Chef comenzó a cocinar para Cliente 1
# 🕒 Tiempo: 5 → Cliente 2 llegó al restaurante
# 🕒 Tiempo: 5 → Cliente 2 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 5 → Cliente 2 está siendo atendido por el mesero
# 🕒 Tiempo: 5 → Cliente 2 pidió 'Spaghetti' con tolerancia de 10 minutos
# 🕒 Tiempo: 5 → Chef comenzó a cocinar para Cliente 2
# 🕒 Tiempo: 8 → Cliente 3 llegó al restaurante
# 🕒 Tiempo: 8 → Cliente 3 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 9 → Cliente 4 llegó al restaurante
# 🕒 Tiempo: 9 → Cliente 4 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 11 → Cliente 1 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 12 → Cliente 2 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 13 → Cliente 5 llegó al restaurante
# 🕒 Tiempo: 13 → Cliente 5 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 17 → Cliente 6 llegó al restaurante
# 🕒 Tiempo: 17 → Cliente 6 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 18 → Cliente 2 terminó de comer y se fue
# 🕒 Tiempo: 18 → Cliente 7 llegó al restaurante
# 🕒 Tiempo: 18 → Cliente 7 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 18 → Cliente 7 está siendo atendido por el mesero
# 🕒 Tiempo: 18 → Cliente 7 pidió 'Pizza' con tolerancia de 14 minutos
# 🕒 Tiempo: 18 → Chef comenzó a cocinar para Cliente 7
# 🕒 Tiempo: 19 → Cliente 1 terminó de comer y se fue
# 🕒 Tiempo: 21 → Cliente 8 llegó al restaurante
# 🕒 Tiempo: 21 → Cliente 8 se sienta en mesa 1 con 4 personas
# 🕒 Tiempo: 21 → Cliente 8 está siendo atendido por el mesero
# 🕒 Tiempo: 21 → Cliente 8 pidió 'Ensalada' con tolerancia de 12 minutos
# 🕒 Tiempo: 21 → Chef comenzó a cocinar para Cliente 8
# 🕒 Tiempo: 24 → Cliente 8 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 25 → Cliente 9 llegó al restaurante
# 🕒 Tiempo: 25 → Cliente 9 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 25 → Cliente 9 está siendo atendido por el mesero
# 🕒 Tiempo: 25 → Cliente 9 pidió 'Hamburguesa' con tolerancia de 15 minutos
# 🕒 Tiempo: 25 → Chef comenzó a cocinar para Cliente 9
# 🕒 Tiempo: 26 → Cliente 10 llegó al restaurante
# 🕒 Tiempo: 26 → Cliente 10 se sienta en mesa 3 con 4 personas
# 🕒 Tiempo: 26 → Cliente 10 está siendo atendido por el mesero
# 🕒 Tiempo: 26 → Cliente 10 pidió 'Hamburguesa' con tolerancia de 9 minutos
# 🕒 Tiempo: 26 → Chef comenzó a cocinar para Cliente 10
# 🕒 Tiempo: 28 → Cliente 7 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 29 → Cliente 11 llegó al restaurante
# 🕒 Tiempo: 29 → Cliente 11 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 30 → Cliente 9 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 31 → Cliente 10 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 32 → Cliente 12 llegó al restaurante
# 🕒 Tiempo: 32 → Cliente 12 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 33 → Cliente 8 terminó de comer y se fue
# 🕒 Tiempo: 33 → Cliente 13 llegó al restaurante
# 🕒 Tiempo: 33 → Cliente 13 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 33 → Cliente 13 está siendo atendido por el mesero
# 🕒 Tiempo: 33 → Cliente 13 pidió 'Ensalada' con tolerancia de 12 minutos
# 🕒 Tiempo: 33 → Chef comenzó a cocinar para Cliente 13
# 🕒 Tiempo: 34 → Cliente 9 terminó de comer y se fue
# 🕒 Tiempo: 35 → Cliente 10 terminó de comer y se fue
# 🕒 Tiempo: 35 → Cliente 14 llegó al restaurante
# 🕒 Tiempo: 35 → Cliente 14 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 35 → Cliente 14 está siendo atendido por el mesero
# 🕒 Tiempo: 35 → Cliente 14 pidió 'Hamburguesa' con tolerancia de 14 minutos
# 🕒 Tiempo: 35 → Chef comenzó a cocinar para Cliente 14
# 🕒 Tiempo: 36 → Cliente 7 terminó de comer y se fue
# 🕒 Tiempo: 36 → Cliente 13 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 39 → Cliente 15 llegó al restaurante
# 🕒 Tiempo: 39 → Cliente 15 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 39 → Cliente 15 está siendo atendido por el mesero
# 🕒 Tiempo: 39 → Cliente 15 pidió 'Ensalada' con tolerancia de 12 minutos
# 🕒 Tiempo: 39 → Chef comenzó a cocinar para Cliente 15
# 🕒 Tiempo: 40 → Cliente 14 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 42 → Cliente 15 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 43 → Cliente 16 llegó al restaurante
# 🕒 Tiempo: 43 → Cliente 16 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 43 → Cliente 16 está siendo atendido por el mesero
# 🕒 Tiempo: 43 → Cliente 16 pidió 'Spaghetti' con tolerancia de 14 minutos
# 🕒 Tiempo: 43 → Chef comenzó a cocinar para Cliente 16
# 🕒 Tiempo: 44 → Cliente 14 terminó de comer y se fue
# 🕒 Tiempo: 44 → Cliente 17 llegó al restaurante
# 🕒 Tiempo: 44 → Cliente 17 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 45 → Cliente 13 terminó de comer y se fue
# 🕒 Tiempo: 45 → Cliente 18 llegó al restaurante
# 🕒 Tiempo: 45 → Cliente 18 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 45 → Cliente 18 está siendo atendido por el mesero
# 🕒 Tiempo: 45 → Cliente 18 pidió 'Ensalada' con tolerancia de 10 minutos
# 🕒 Tiempo: 45 → Chef comenzó a cocinar para Cliente 18
# 🕒 Tiempo: 48 → Cliente 18 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 49 → Cliente 19 llegó al restaurante
# 🕒 Tiempo: 49 → Cliente 19 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 50 → Cliente 16 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 51 → Cliente 15 terminó de comer y se fue
# 🕒 Tiempo: 52 → Cliente 20 llegó al restaurante
# 🕒 Tiempo: 52 → Cliente 20 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 56 → Cliente 16 terminó de comer y se fue
# 🕒 Tiempo: 56 → Cliente 21 llegó al restaurante
# 🕒 Tiempo: 56 → Cliente 21 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 57 → Cliente 18 terminó de comer y se fue
# 🕒 Tiempo: 57 → Cliente 22 llegó al restaurante
# 🕒 Tiempo: 57 → Cliente 22 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 57 → Cliente 22 está siendo atendido por el mesero
# 🕒 Tiempo: 57 → Cliente 22 pidió 'Spaghetti' con tolerancia de 15 minutos
# 🕒 Tiempo: 57 → Chef comenzó a cocinar para Cliente 22
# 🕒 Tiempo: 61 → Cliente 23 llegó al restaurante
# 🕒 Tiempo: 61 → Cliente 23 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 61 → Cliente 23 está siendo atendido por el mesero
# 🕒 Tiempo: 61 → Cliente 23 pidió 'Spaghetti' con tolerancia de 14 minutos
# 🕒 Tiempo: 61 → Chef comenzó a cocinar para Cliente 23
# 🕒 Tiempo: 63 → Cliente 24 llegó al restaurante
# 🕒 Tiempo: 63 → Cliente 24 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 64 → Cliente 22 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 64 → Cliente 25 llegó al restaurante
# 🕒 Tiempo: 64 → Cliente 25 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 65 → Cliente 26 llegó al restaurante
# 🕒 Tiempo: 65 → Cliente 26 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 68 → Cliente 23 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 68 → Cliente 27 llegó al restaurante
# 🕒 Tiempo: 68 → Cliente 27 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 70 → Cliente 22 terminó de comer y se fue
# 🕒 Tiempo: 71 → Cliente 28 llegó al restaurante
# 🕒 Tiempo: 71 → Cliente 28 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 71 → Cliente 28 está siendo atendido por el mesero
# 🕒 Tiempo: 71 → Cliente 28 pidió 'Ensalada' con tolerancia de 8 minutos
# 🕒 Tiempo: 71 → Chef comenzó a cocinar para Cliente 28
# 🕒 Tiempo: 74 → Cliente 23 terminó de comer y se fue
# 🕒 Tiempo: 74 → Cliente 29 llegó al restaurante
# 🕒 Tiempo: 74 → Cliente 28 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 74 → Cliente 29 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 74 → Cliente 29 está siendo atendido por el mesero
# 🕒 Tiempo: 74 → Cliente 29 pidió 'Hamburguesa' con tolerancia de 10 minutos
# 🕒 Tiempo: 74 → Chef comenzó a cocinar para Cliente 29
# 🕒 Tiempo: 78 → Cliente 30 llegó al restaurante
# 🕒 Tiempo: 78 → Cliente 30 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 78 → Cliente 30 está siendo atendido por el mesero
# 🕒 Tiempo: 78 → Cliente 30 pidió 'Ensalada' con tolerancia de 8 minutos
# 🕒 Tiempo: 78 → Chef comenzó a cocinar para Cliente 30
# 🕒 Tiempo: 79 → Cliente 29 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 81 → Cliente 31 llegó al restaurante
# 🕒 Tiempo: 81 → Cliente 30 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 81 → Cliente 31 se sienta en mesa 3 con 3 personas
# 🕒 Tiempo: 81 → Cliente 31 está siendo atendido por el mesero
# 🕒 Tiempo: 81 → Cliente 31 pidió 'Spaghetti' con tolerancia de 7 minutos
# 🕒 Tiempo: 81 → Chef comenzó a cocinar para Cliente 31
# 🕒 Tiempo: 83 → Cliente 28 terminó de comer y se fue
# 🕒 Tiempo: 83 → Cliente 29 terminó de comer y se fue
# 🕒 Tiempo: 85 → Cliente 32 llegó al restaurante
# 🕒 Tiempo: 85 → Cliente 32 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 85 → Cliente 32 está siendo atendido por el mesero
# 🕒 Tiempo: 85 → Cliente 32 pidió 'Hamburguesa' con tolerancia de 10 minutos
# 🕒 Tiempo: 85 → Chef comenzó a cocinar para Cliente 32
# 🕒 Tiempo: 87 → Cliente 33 llegó al restaurante
# 🕒 Tiempo: 87 → Cliente 33 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 88 → Cliente 31 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 88 → Cliente 34 llegó al restaurante
# 🕒 Tiempo: 88 → Cliente 34 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 90 → Cliente 30 terminó de comer y se fue
# 🕒 Tiempo: 90 → Cliente 32 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 91 → Cliente 35 llegó al restaurante
# 🕒 Tiempo: 91 → Cliente 35 se sienta en mesa 2 con 4 personas
# 🕒 Tiempo: 91 → Cliente 35 está siendo atendido por el mesero
# 🕒 Tiempo: 91 → Cliente 35 pidió 'Ensalada' con tolerancia de 12 minutos
# 🕒 Tiempo: 91 → Chef comenzó a cocinar para Cliente 35
# 🕒 Tiempo: 93 → Cliente 36 llegó al restaurante
# 🕒 Tiempo: 93 → Cliente 36 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 93 → Cliente 36 está siendo atendido por el mesero
# 🕒 Tiempo: 93 → Cliente 36 pidió 'Hamburguesa' con tolerancia de 9 minutos
# 🕒 Tiempo: 93 → Chef comenzó a cocinar para Cliente 36
# 🕒 Tiempo: 94 → Cliente 31 terminó de comer y se fue
# 🕒 Tiempo: 94 → Cliente 32 terminó de comer y se fue
# 🕒 Tiempo: 94 → Cliente 35 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 97 → Cliente 37 llegó al restaurante
# 🕒 Tiempo: 97 → Cliente 37 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 97 → Cliente 37 está siendo atendido por el mesero
# 🕒 Tiempo: 97 → Cliente 37 pidió 'Pizza' con tolerancia de 12 minutos
# 🕒 Tiempo: 97 → Chef comenzó a cocinar para Cliente 37
# 🕒 Tiempo: 98 → Cliente 36 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 100 → Cliente 38 llegó al restaurante
# 🕒 Tiempo: 100 → Cliente 38 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 100 → Cliente 38 está siendo atendido por el mesero
# 🕒 Tiempo: 100 → Cliente 38 pidió 'Spaghetti' con tolerancia de 10 minutos
# 🕒 Tiempo: 100 → Chef comenzó a cocinar para Cliente 38
# 🕒 Tiempo: 101 → Cliente 39 llegó al restaurante
# 🕒 Tiempo: 101 → Cliente 39 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 102 → Cliente 36 terminó de comer y se fue
# 🕒 Tiempo: 102 → Cliente 39 está siendo atendido por el mesero
# 🕒 Tiempo: 102 → Cliente 39 pidió 'Hamburguesa' con tolerancia de 14 minutos
# 🕒 Tiempo: 102 → Chef comenzó a cocinar para Cliente 39
# 🕒 Tiempo: 103 → Cliente 35 terminó de comer y se fue
# 🕒 Tiempo: 104 → Cliente 40 llegó al restaurante
# 🕒 Tiempo: 104 → Cliente 40 se sienta en mesa 2 con 4 personas
# 🕒 Tiempo: 104 → Cliente 40 está siendo atendido por el mesero
# 🕒 Tiempo: 104 → Cliente 40 pidió 'Ensalada' con tolerancia de 13 minutos
# 🕒 Tiempo: 104 → Chef comenzó a cocinar para Cliente 40
# 🕒 Tiempo: 106 → Cliente 41 llegó al restaurante
# 🕒 Tiempo: 106 → Cliente 41 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 107 → Cliente 37 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 107 → Cliente 38 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 107 → Cliente 39 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 107 → Cliente 40 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 108 → Cliente 42 llegó al restaurante
# 🕒 Tiempo: 108 → Cliente 42 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 111 → Cliente 39 terminó de comer y se fue
# 🕒 Tiempo: 111 → Cliente 42 está siendo atendido por el mesero
# 🕒 Tiempo: 111 → Cliente 42 pidió 'Hamburguesa' con tolerancia de 6 minutos
# 🕒 Tiempo: 111 → Chef comenzó a cocinar para Cliente 42
# 🕒 Tiempo: 112 → Cliente 43 llegó al restaurante
# 🕒 Tiempo: 112 → Cliente 43 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 113 → Cliente 38 terminó de comer y se fue
# 🕒 Tiempo: 113 → Cliente 43 está siendo atendido por el mesero
# 🕒 Tiempo: 113 → Cliente 43 pidió 'Ensalada' con tolerancia de 10 minutos
# 🕒 Tiempo: 113 → Chef comenzó a cocinar para Cliente 43
# 🕒 Tiempo: 115 → Cliente 37 terminó de comer y se fue
# 🕒 Tiempo: 115 → Cliente 44 llegó al restaurante
# 🕒 Tiempo: 115 → Cliente 44 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 115 → Cliente 44 está siendo atendido por el mesero
# 🕒 Tiempo: 115 → Cliente 44 pidió 'Hamburguesa' con tolerancia de 11 minutos
# 🕒 Tiempo: 115 → Chef comenzó a cocinar para Cliente 44
# 🕒 Tiempo: 116 → Cliente 40 terminó de comer y se fue
# 🕒 Tiempo: 116 → Cliente 42 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 116 → Cliente 43 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 116 → Cliente 45 llegó al restaurante
# 🕒 Tiempo: 116 → Cliente 45 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 117 → Cliente 46 llegó al restaurante
# 🕒 Tiempo: 117 → Cliente 46 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 120 → Cliente 44 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 120 → Cliente 42 terminó de comer y se fue
# 🕒 Tiempo: 121 → Cliente 47 llegó al restaurante
# 🕒 Tiempo: 121 → Cliente 47 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 121 → Cliente 47 está siendo atendido por el mesero
# 🕒 Tiempo: 121 → Cliente 47 pidió 'Hamburguesa' con tolerancia de 8 minutos
# 🕒 Tiempo: 121 → Chef comenzó a cocinar para Cliente 47
# 🕒 Tiempo: 123 → Cliente 48 llegó al restaurante
# 🕒 Tiempo: 123 → Cliente 48 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 123 → Cliente 48 está siendo atendido por el mesero
# 🕒 Tiempo: 123 → Cliente 48 pidió 'Pizza' con tolerancia de 12 minutos
# 🕒 Tiempo: 123 → Chef comenzó a cocinar para Cliente 48
# 🕒 Tiempo: 124 → Cliente 44 terminó de comer y se fue
# 🕒 Tiempo: 125 → Cliente 43 terminó de comer y se fue
# 🕒 Tiempo: 125 → Cliente 49 llegó al restaurante
# 🕒 Tiempo: 125 → Cliente 49 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 125 → Cliente 49 está siendo atendido por el mesero
# 🕒 Tiempo: 125 → Cliente 49 pidió 'Pizza' con tolerancia de 8 minutos
# 🕒 Tiempo: 125 → Chef comenzó a cocinar para Cliente 49
# 🕒 Tiempo: 126 → Cliente 47 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 129 → Cliente 50 llegó al restaurante
# 🕒 Tiempo: 129 → Cliente 50 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 129 → Cliente 50 está siendo atendido por el mesero
# 🕒 Tiempo: 129 → Cliente 50 pidió 'Pizza' con tolerancia de 5 minutos
# 🕒 Tiempo: 129 → Chef comenzó a cocinar para Cliente 50
# 🕒 Tiempo: 130 → Cliente 47 terminó de comer y se fue
# 🕒 Tiempo: 132 → Cliente 51 llegó al restaurante
# 🕒 Tiempo: 132 → Cliente 51 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 132 → Cliente 51 está siendo atendido por el mesero
# 🕒 Tiempo: 132 → Cliente 51 pidió 'Ensalada' con tolerancia de 14 minutos
# 🕒 Tiempo: 132 → Chef comenzó a cocinar para Cliente 51
# 🕒 Tiempo: 133 → Cliente 48 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 135 → Cliente 49 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 135 → Cliente 51 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 136 → Cliente 52 llegó al restaurante
# 🕒 Tiempo: 136 → Cliente 52 se sienta en mesa 3 con 3 personas
# 🕒 Tiempo: 138 → Cliente 53 llegó al restaurante
# 🕒 Tiempo: 138 → Cliente 53 se sienta en mesa 3 con 3 personas
# 🕒 Tiempo: 139 → Cliente 50 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 141 → Cliente 48 terminó de comer y se fue
# 🕒 Tiempo: 141 → Cliente 52 está siendo atendido por el mesero
# 🕒 Tiempo: 141 → Cliente 52 pidió 'Ensalada' con tolerancia de 13 minutos
# 🕒 Tiempo: 141 → Chef comenzó a cocinar para Cliente 52
# 🕒 Tiempo: 142 → Cliente 54 llegó al restaurante
# 🕒 Tiempo: 142 → Cliente 54 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 143 → Cliente 49 terminó de comer y se fue
# 🕒 Tiempo: 143 → Cliente 53 está siendo atendido por el mesero
# 🕒 Tiempo: 143 → Cliente 53 pidió 'Hamburguesa' con tolerancia de 7 minutos
# 🕒 Tiempo: 143 → Chef comenzó a cocinar para Cliente 53
# 🕒 Tiempo: 144 → Cliente 51 terminó de comer y se fue
# 🕒 Tiempo: 144 → Cliente 52 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 145 → Cliente 55 llegó al restaurante
# 🕒 Tiempo: 145 → Cliente 55 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 145 → Cliente 55 está siendo atendido por el mesero
# 🕒 Tiempo: 145 → Cliente 55 pidió 'Pizza' con tolerancia de 10 minutos
# 🕒 Tiempo: 145 → Chef comenzó a cocinar para Cliente 55
# 🕒 Tiempo: 147 → Cliente 50 terminó de comer y se fue
# 🕒 Tiempo: 148 → Cliente 53 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 148 → Cliente 56 llegó al restaurante
# 🕒 Tiempo: 148 → Cliente 56 se sienta en mesa 2 con 3 personas
# 🕒 Tiempo: 148 → Cliente 56 está siendo atendido por el mesero
# 🕒 Tiempo: 148 → Cliente 56 pidió 'Spaghetti' con tolerancia de 13 minutos
# 🕒 Tiempo: 148 → Chef comenzó a cocinar para Cliente 56
# 🕒 Tiempo: 151 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 152 → Cliente 53 terminó de comer y se fue
# 🕒 Tiempo: 153 → Cliente 52 terminó de comer y se fue
# 🕒 Tiempo: 153 → Cliente 57 llegó al restaurante
# 🕒 Tiempo: 153 → Cliente 57 se sienta en mesa 3 con 3 personas
# 🕒 Tiempo: 153 → Cliente 57 está siendo atendido por el mesero
# 🕒 Tiempo: 153 → Cliente 57 pidió 'Spaghetti' con tolerancia de 8 minutos
# 🕒 Tiempo: 153 → Chef comenzó a cocinar para Cliente 57
# 🕒 Tiempo: 155 → Cliente 55 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 155 → Cliente 56 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 155 → Cliente 58 llegó al restaurante
# 🕒 Tiempo: 155 → Cliente 58 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 158 → Cliente 59 llegó al restaurante
# 🕒 Tiempo: 158 → Cliente 59 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 158 → Cliente 59 está siendo atendido por el mesero
# 🕒 Tiempo: 158 → Cliente 59 pidió 'Hamburguesa' con tolerancia de 14 minutos
# 🕒 Tiempo: 158 → Chef comenzó a cocinar para Cliente 59
# 🕒 Tiempo: 160 → Cliente 57 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 160 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 161 → Cliente 56 terminó de comer y se fue
# 🕒 Tiempo: 162 → Cliente 60 llegó al restaurante
# 🕒 Tiempo: 162 → Cliente 60 se sienta en mesa 2 con 3 personas
# 🕒 Tiempo: 162 → Cliente 60 está siendo atendido por el mesero
# 🕒 Tiempo: 162 → Cliente 60 pidió 'Ensalada' con tolerancia de 9 minutos
# 🕒 Tiempo: 162 → Chef comenzó a cocinar para Cliente 60
# 🕒 Tiempo: 163 → Cliente 55 terminó de comer y se fue
# 🕒 Tiempo: 163 → Cliente 59 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 163 → Cliente 61 llegó al restaurante
# 🕒 Tiempo: 163 → Cliente 61 se sienta en mesa 1 con 4 personas
# 🕒 Tiempo: 163 → Cliente 61 está siendo atendido por el mesero
# 🕒 Tiempo: 163 → Cliente 61 pidió 'Ensalada' con tolerancia de 12 minutos
# 🕒 Tiempo: 163 → Chef comenzó a cocinar para Cliente 61
# 🕒 Tiempo: 165 → Cliente 60 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 166 → Cliente 57 terminó de comer y se fue
# 🕒 Tiempo: 166 → Cliente 61 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 167 → Cliente 59 terminó de comer y se fue
# 🕒 Tiempo: 167 → Cliente 62 llegó al restaurante
# 🕒 Tiempo: 167 → Cliente 62 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 167 → Cliente 62 está siendo atendido por el mesero
# 🕒 Tiempo: 167 → Cliente 62 pidió 'Ensalada' con tolerancia de 7 minutos
# 🕒 Tiempo: 167 → Chef comenzó a cocinar para Cliente 62
# 🕒 Tiempo: 168 → Cliente 63 llegó al restaurante
# 🕒 Tiempo: 168 → Cliente 63 se sienta en mesa 3 con 4 personas
# 🕒 Tiempo: 168 → Cliente 63 está siendo atendido por el mesero
# 🕒 Tiempo: 168 → Cliente 63 pidió 'Hamburguesa' con tolerancia de 15 minutos
# 🕒 Tiempo: 168 → Chef comenzó a cocinar para Cliente 63
# 🕒 Tiempo: 169 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 170 → Cliente 62 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 173 → Cliente 63 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 173 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 174 → Cliente 60 terminó de comer y se fue
# 🕒 Tiempo: 175 → Cliente 61 terminó de comer y se fue
# 🕒 Tiempo: 175 → Cliente 64 llegó al restaurante
# 🕒 Tiempo: 175 → Cliente 64 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 175 → Cliente 64 está siendo atendido por el mesero
# 🕒 Tiempo: 175 → Cliente 64 pidió 'Spaghetti' con tolerancia de 15 minutos
# 🕒 Tiempo: 175 → Chef comenzó a cocinar para Cliente 64
# 🕒 Tiempo: 177 → Cliente 63 terminó de comer y se fue
# 🕒 Tiempo: 178 → Cliente 65 llegó al restaurante
# 🕒 Tiempo: 178 → Cliente 65 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 179 → Cliente 62 terminó de comer y se fue
# 🕒 Tiempo: 181 → Cliente 66 llegó al restaurante
# 🕒 Tiempo: 181 → Cliente 66 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 182 → Cliente 64 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 185 → Cliente 67 llegó al restaurante
# 🕒 Tiempo: 185 → Cliente 67 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 188 → Cliente 64 terminó de comer y se fue
# 🕒 Tiempo: 189 → Cliente 68 llegó al restaurante
# 🕒 Tiempo: 189 → Cliente 68 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 189 → Cliente 68 está siendo atendido por el mesero
# 🕒 Tiempo: 189 → Cliente 68 pidió 'Hamburguesa' con tolerancia de 15 minutos
# 🕒 Tiempo: 189 → Chef comenzó a cocinar para Cliente 68
# 🕒 Tiempo: 193 → Cliente 69 llegó al restaurante
# 🕒 Tiempo: 193 → Cliente 69 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 194 → Cliente 68 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 196 → Cliente 70 llegó al restaurante
# 🕒 Tiempo: 196 → Cliente 70 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 198 → Cliente 68 terminó de comer y se fue
# 🕒 Tiempo: 200 → Cliente 71 llegó al restaurante
# 🕒 Tiempo: 200 → Cliente 71 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 200 → Cliente 71 está siendo atendido por el mesero
# 🕒 Tiempo: 200 → Cliente 71 pidió 'Spaghetti' con tolerancia de 13 minutos
# 🕒 Tiempo: 200 → Chef comenzó a cocinar para Cliente 71
# 🕒 Tiempo: 203 → Cliente 72 llegó al restaurante
# 🕒 Tiempo: 203 → Cliente 72 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 206 → Cliente 73 llegó al restaurante
# 🕒 Tiempo: 206 → Cliente 73 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 207 → Cliente 71 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 207 → Cliente 74 llegó al restaurante
# 🕒 Tiempo: 207 → Cliente 74 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 211 → Cliente 75 llegó al restaurante
# 🕒 Tiempo: 211 → Cliente 75 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 213 → Cliente 71 terminó de comer y se fue
# 🕒 Tiempo: 213 → Cliente 76 llegó al restaurante
# 🕒 Tiempo: 213 → Cliente 76 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 213 → Cliente 76 está siendo atendido por el mesero
# 🕒 Tiempo: 213 → Cliente 76 pidió 'Pizza' con tolerancia de 14 minutos
# 🕒 Tiempo: 213 → Chef comenzó a cocinar para Cliente 76
# 🕒 Tiempo: 215 → Cliente 77 llegó al restaurante
# 🕒 Tiempo: 215 → Cliente 77 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 215 → Cliente 77 está siendo atendido por el mesero
# 🕒 Tiempo: 215 → Cliente 77 pidió 'Spaghetti' con tolerancia de 15 minutos
# 🕒 Tiempo: 215 → Chef comenzó a cocinar para Cliente 77
# 🕒 Tiempo: 219 → Cliente 78 llegó al restaurante
# 🕒 Tiempo: 219 → Cliente 78 se sienta en mesa 2 con 3 personas
# 🕒 Tiempo: 219 → Cliente 78 está siendo atendido por el mesero
# 🕒 Tiempo: 219 → Cliente 78 pidió 'Ensalada' con tolerancia de 6 minutos
# 🕒 Tiempo: 219 → Chef comenzó a cocinar para Cliente 78
# 🕒 Tiempo: 220 → Cliente 79 llegó al restaurante
# 🕒 Tiempo: 220 → Cliente 79 se sienta en mesa 3 con 4 personas
# 🕒 Tiempo: 220 → Cliente 79 está siendo atendido por el mesero
# 🕒 Tiempo: 220 → Cliente 79 pidió 'Ensalada' con tolerancia de 15 minutos
# 🕒 Tiempo: 220 → Chef comenzó a cocinar para Cliente 79
# 🕒 Tiempo: 222 → Cliente 77 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 222 → Cliente 78 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 223 → Cliente 76 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 223 → Cliente 79 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 224 → Cliente 80 llegó al restaurante
# 🕒 Tiempo: 224 → Cliente 80 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 226 → Cliente 81 llegó al restaurante
# 🕒 Tiempo: 226 → Cliente 81 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 227 → Cliente 82 llegó al restaurante
# 🕒 Tiempo: 227 → Cliente 82 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 228 → Cliente 77 terminó de comer y se fue
# 🕒 Tiempo: 229 → Cliente 83 llegó al restaurante
# 🕒 Tiempo: 229 → Cliente 83 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 231 → Cliente 78 terminó de comer y se fue
# 🕒 Tiempo: 231 → Cliente 76 terminó de comer y se fue
# 🕒 Tiempo: 232 → Cliente 79 terminó de comer y se fue
# 🕒 Tiempo: 232 → Cliente 84 llegó al restaurante
# 🕒 Tiempo: 232 → Cliente 84 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 232 → Cliente 84 está siendo atendido por el mesero
# 🕒 Tiempo: 232 → Cliente 84 pidió 'Hamburguesa' con tolerancia de 6 minutos
# 🕒 Tiempo: 232 → Chef comenzó a cocinar para Cliente 84
# 🕒 Tiempo: 234 → Cliente 85 llegó al restaurante
# 🕒 Tiempo: 234 → Cliente 85 se sienta en mesa 2 con 3 personas
# 🕒 Tiempo: 234 → Cliente 85 está siendo atendido por el mesero
# 🕒 Tiempo: 234 → Cliente 85 pidió 'Hamburguesa' con tolerancia de 8 minutos
# 🕒 Tiempo: 234 → Chef comenzó a cocinar para Cliente 85
# 🕒 Tiempo: 236 → Cliente 86 llegó al restaurante
# 🕒 Tiempo: 236 → Cliente 86 se sienta en mesa 3 con 4 personas
# 🕒 Tiempo: 236 → Cliente 86 está siendo atendido por el mesero
# 🕒 Tiempo: 236 → Cliente 86 pidió 'Hamburguesa' con tolerancia de 15 minutos
# 🕒 Tiempo: 236 → Chef comenzó a cocinar para Cliente 86
# 🕒 Tiempo: 237 → Cliente 84 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 237 → Cliente 87 llegó al restaurante
# 🕒 Tiempo: 237 → Cliente 87 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 239 → Cliente 85 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 240 → Cliente 88 llegó al restaurante
# 🕒 Tiempo: 240 → Cliente 88 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 240 → Cliente 88 está siendo atendido por el mesero
# 🕒 Tiempo: 240 → Cliente 88 pidió 'Spaghetti' con tolerancia de 14 minutos
# 🕒 Tiempo: 240 → Chef comenzó a cocinar para Cliente 88
# 🕒 Tiempo: 241 → Cliente 86 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 241 → Cliente 84 terminó de comer y se fue
# 🕒 Tiempo: 241 → Cliente 89 llegó al restaurante
# 🕒 Tiempo: 241 → Cliente 89 se sienta en mesa 1 con 4 personas
# 🕒 Tiempo: 241 → Cliente 89 está siendo atendido por el mesero
# 🕒 Tiempo: 241 → Cliente 89 pidió 'Pizza' con tolerancia de 10 minutos
# 🕒 Tiempo: 241 → Chef comenzó a cocinar para Cliente 89
# 🕒 Tiempo: 242 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 243 → Cliente 85 terminó de comer y se fue
# 🕒 Tiempo: 243 → Cliente 90 llegó al restaurante
# 🕒 Tiempo: 243 → Cliente 90 se sienta en mesa 2 con 4 personas
# 🕒 Tiempo: 243 → Cliente 90 está siendo atendido por el mesero
# 🕒 Tiempo: 243 → Cliente 90 pidió 'Hamburguesa' con tolerancia de 5 minutos
# 🕒 Tiempo: 243 → Chef comenzó a cocinar para Cliente 90
# 🕒 Tiempo: 244 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 245 → Cliente 86 terminó de comer y se fue
# 🕒 Tiempo: 247 → Cliente 88 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 248 → Cliente 90 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 248 → Cliente 91 llegó al restaurante
# 🕒 Tiempo: 248 → Cliente 91 se sienta en mesa 3 con 3 personas
# 🕒 Tiempo: 248 → Cliente 91 está siendo atendido por el mesero
# 🕒 Tiempo: 248 → Cliente 91 pidió 'Spaghetti' con tolerancia de 5 minutos
# 🕒 Tiempo: 248 → Chef comenzó a cocinar para Cliente 91
# 🕒 Tiempo: 251 → Cliente 89 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 251 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 252 → Cliente 90 terminó de comer y se fue
# 🕒 Tiempo: 253 → Cliente 88 terminó de comer y se fue
# 🕒 Tiempo: 253 → Cliente 92 llegó al restaurante
# 🕒 Tiempo: 253 → Cliente 92 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 253 → Cliente 92 está siendo atendido por el mesero
# 🕒 Tiempo: 253 → Cliente 92 pidió 'Pizza' con tolerancia de 15 minutos
# 🕒 Tiempo: 253 → Chef comenzó a cocinar para Cliente 92
# 🕒 Tiempo: 255 → Cliente 91 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 257 → Cliente 93 llegó al restaurante
# 🕒 Tiempo: 257 → Cliente 93 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 259 → Cliente 89 terminó de comer y se fue
# 🕒 Tiempo: 260 → Cliente 94 llegó al restaurante
# 🕒 Tiempo: 260 → Cliente 94 se sienta en mesa 1 con 2 personas
# 🕒 Tiempo: 260 → Cliente 94 está siendo atendido por el mesero
# 🕒 Tiempo: 260 → Cliente 94 pidió 'Hamburguesa' con tolerancia de 15 minutos
# 🕒 Tiempo: 260 → Chef comenzó a cocinar para Cliente 94
# 🕒 Tiempo: 261 → Cliente 91 terminó de comer y se fue
# 🕒 Tiempo: 262 → Cliente 95 llegó al restaurante
# 🕒 Tiempo: 262 → Cliente 95 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 263 → Cliente 92 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 265 → Cliente 94 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 266 → Cliente 96 llegó al restaurante
# 🕒 Tiempo: 266 → Cliente 96 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 268 → Cliente 97 llegó al restaurante
# 🕒 Tiempo: 268 → Cliente 97 se fue porque no hay suficientes sillas
# 🕒 Tiempo: 269 → Cliente 94 terminó de comer y se fue
# 🕒 Tiempo: 269 → Cliente 98 llegó al restaurante
# 🕒 Tiempo: 269 → Cliente 98 se sienta en mesa 1 con 4 personas
# 🕒 Tiempo: 269 → Cliente 98 está siendo atendido por el mesero
# 🕒 Tiempo: 269 → Cliente 98 pidió 'Hamburguesa' con tolerancia de 6 minutos
# 🕒 Tiempo: 269 → Chef comenzó a cocinar para Cliente 98
# 🕒 Tiempo: 271 → Cliente 92 terminó de comer y se fue
# 🕒 Tiempo: 272 → Cliente 99 llegó al restaurante
# 🕒 Tiempo: 272 → Cliente 99 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 272 → Cliente 99 está siendo atendido por el mesero
# 🕒 Tiempo: 272 → Cliente 99 pidió 'Pizza' con tolerancia de 10 minutos
# 🕒 Tiempo: 272 → Chef comenzó a cocinar para Cliente 99
# 🕒 Tiempo: 274 → Cliente 98 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 274 → Cliente 100 llegó al restaurante
# 🕒 Tiempo: 274 → Cliente 100 se sienta en mesa 2 con 2 personas
# 🕒 Tiempo: 274 → Cliente 100 está siendo atendido por el mesero
# 🕒 Tiempo: 274 → Cliente 100 pidió 'Pizza' con tolerancia de 12 minutos
# 🕒 Tiempo: 274 → Chef comenzó a cocinar para Cliente 100
# 🕒 Tiempo: 276 → Cliente 101 llegó al restaurante
# 🕒 Tiempo: 276 → Cliente 101 se sienta en mesa 3 con 4 personas
# 🕒 Tiempo: 276 → Cliente 101 está siendo atendido por el mesero
# 🕒 Tiempo: 276 → Cliente 101 pidió 'Ensalada' con tolerancia de 10 minutos
# 🕒 Tiempo: 276 → Chef comenzó a cocinar para Cliente 101
# 🕒 Tiempo: 278 → Cliente 98 terminó de comer y se fue
# 🕒 Tiempo: 279 → Cliente 101 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 280 → Cliente 102 llegó al restaurante
# 🕒 Tiempo: 280 → Cliente 102 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 280 → Cliente 102 está siendo atendido por el mesero
# 🕒 Tiempo: 280 → Cliente 102 pidió 'Hamburguesa' con tolerancia de 6 minutos
# 🕒 Tiempo: 280 → Chef comenzó a cocinar para Cliente 102
# 🕒 Tiempo: 281 → Cliente 103 llegó al restaurante
# 🕒 Tiempo: 281 → Cliente 103 se sienta en mesa 3 con 2 personas
# 🕒 Tiempo: 282 → Cliente 99 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 283 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 284 → Cliente 100 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 285 → Cliente 102 recibió su comida y empezó a comer 'Hamburguesa'
# 🕒 Tiempo: 285 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 288 → Cliente 101 terminó de comer y se fue
# 🕒 Tiempo: 288 → Cliente 103 está siendo atendido por el mesero
# 🕒 Tiempo: 288 → Cliente 103 pidió 'Pizza' con tolerancia de 10 minutos
# 🕒 Tiempo: 288 → Chef comenzó a cocinar para Cliente 103
# 🕒 Tiempo: 289 → Cliente 102 terminó de comer y se fue
# 🕒 Tiempo: 289 → Cliente 104 llegó al restaurante
# 🕒 Tiempo: 289 → Cliente 104 se sienta en mesa 1 con 3 personas
# 🕒 Tiempo: 289 → Cliente 104 está siendo atendido por el mesero
# 🕒 Tiempo: 289 → Cliente 104 pidió 'Spaghetti' con tolerancia de 5 minutos
# 🕒 Tiempo: 289 → Chef comenzó a cocinar para Cliente 104
# 🕒 Tiempo: 290 → Cliente 99 terminó de comer y se fue
# 🕒 Tiempo: 292 → Cliente 100 terminó de comer y se fue
# 🕒 Tiempo: 292 → Cliente 105 llegó al restaurante
# 🕒 Tiempo: 292 → Cliente 105 se sienta en mesa 2 con 3 personas
# 🕒 Tiempo: 292 → Cliente 105 está siendo atendido por el mesero
# 🕒 Tiempo: 292 → Cliente 105 pidió 'Spaghetti' con tolerancia de 15 minutos
# 🕒 Tiempo: 292 → Chef comenzó a cocinar para Cliente 105
# 🕒 Tiempo: 293 → Cliente 106 llegó al restaurante
# 🕒 Tiempo: 293 → Cliente 106 se sienta en mesa 3 con 4 personas
# 🕒 Tiempo: 293 → Cliente 106 está siendo atendido por el mesero
# 🕒 Tiempo: 293 → Cliente 106 pidió 'Ensalada' con tolerancia de 15 minutos
# 🕒 Tiempo: 293 → Chef comenzó a cocinar para Cliente 106
# 🕒 Tiempo: 296 → Cliente 104 recibió su comida y empezó a comer 'Spaghetti'
# 🕒 Tiempo: 296 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 296 → Cliente 106 recibió su comida y empezó a comer 'Ensalada'
# 🕒 Tiempo: 298 → Cliente 103 recibió su comida y empezó a comer 'Pizza'
# 🕒 Tiempo: 298 → No hay mesas disponibles para nuevos clientes.
# 🕒 Tiempo: 299 → Cliente 105 recibió su comida y empezó a comer 'Spaghetti'

# %%
lista_clientes = []

for c in simulacion.clientes:
    lista_clientes.append({
        "id": c.id,
        "grupo_size": c.grupo_size,
        "mesa_id": c.mesa.id if hasattr(c, 'mesa') and c.mesa else None, 
        "plato_seleccionado": c.plato.nombre if c.plato else None, 
        "tiempo_comida": c.plato.tiempo_comida if c.plato else None,  
        "tolerancia_espera_chef": c.tolerancia_chef 
    })

df_clientes = pd.DataFrame(lista_clientes)

# %%
df_clientes
# Out:
#       id  grupo_size  mesa_id plato_seleccionado  tiempo_comida  \
# 0      1           4        1              Pizza            8.0
# 1      2           2        2          Spaghetti            6.0
# 2      3           3        2               None            NaN
# 3      4           4        2               None            NaN
# 4      5           4        2               None            NaN
# ..   ...         ...      ...                ...            ...
# 101  102           3        1        Hamburguesa            4.0
# 102  103           2        3              Pizza            8.0
# 103  104           3        1          Spaghetti            6.0
# 104  105           3        2          Spaghetti            6.0
# 105  106           4        3           Ensalada            9.0
#
#      tolerancia_espera_chef
# 0                        14
# 1                        10
# 2                         9
# 3                        12
# 4                         7
# ..                      ...
# 101                       6
# 102                      10
# 103                       5
# 104                      15
# 105                      15
#
# [106 rows x 6 columns]

# %%
lista_eventos = []

for c in simulacion.clientes:
    lista_eventos.append(c.eventos)

df_eventos = pd.concat(lista_eventos).reset_index(drop=True)

# %%
df_eventos
# Out:
#       id          evento  time
# 0      1           LLEGO     1
# 1      1        ATENDIDO     1
# 2      1  TERMINO COMIDA    19
# 3      2           LLEGO     5
# 4      2        ATENDIDO     5
# ..   ...             ...   ...
# 270  104        ATENDIDO   289
# 271  105           LLEGO   292
# 272  105        ATENDIDO   292
# 273  106           LLEGO   293
# 274  106        ATENDIDO   293
#
# [275 rows x 3 columns]

# %% [markdown]
# #### Preguntas

# %% [markdown]
# 1) ¿Cuánto tiempo de espera tuvieron los clientes antes de sentarse en una mesa?

# %%
llegadas = df_eventos[df_eventos['evento'] == 'LLEGO'].set_index('id')
atendidos = df_eventos[df_eventos['evento'] == 'ATENDIDO'].set_index('id')

tiempos_espera = pd.DataFrame()
tiempos_espera['tiempo_llegada'] = llegadas['time']
tiempos_espera['tiempo_atendido'] = atendidos['time']
tiempos_espera['espera_para_sentarse'] = tiempos_espera['tiempo_atendido'] - tiempos_espera['tiempo_llegada']

promedio_espera = tiempos_espera['espera_para_sentarse'].mean()
max_espera = tiempos_espera['espera_para_sentarse'].max()
min_espera = tiempos_espera['espera_para_sentarse'].min()

print(f"Tiempo promedio de espera para sentarse: {promedio_espera:.2f} minutos")
print(f"Tiempo máximo de espera: {max_espera:.2f} minutos")
print(f"Tiempo mínimo de espera: {min_espera:.2f} minutos")
# Out:
# Tiempo promedio de espera para sentarse: 0.33 minutos
# Tiempo máximo de espera: 7.00 minutos
# Tiempo mínimo de espera: 0.00 minutos

# %% [markdown]
# 2. ¿Qué plato fue el más solicitado y cuánto tiempo promedio pasaron los clientes comiendo?

# %%
platos_count = df_clientes['plato_seleccionado'].value_counts()
tiempo_promedio_por_plato = df_clientes.groupby('plato_seleccionado')['tiempo_comida'].mean()

plato_mas_popular = platos_count.idxmax()
cantidad_plato_popular = platos_count.max()

print(f"El plato más solicitado fue: {plato_mas_popular} con {cantidad_plato_popular} pedidos")
print("\nTiempo promedio de comida por plato:")
for plato, tiempo in tiempo_promedio_por_plato.items():
    print(f"{plato}: {tiempo:.2f} minutos")
# Out:
# El plato más solicitado fue: Hamburguesa con 21 pedidos
#
# Tiempo promedio de comida por plato:
# Ensalada: 9.00 minutos
# Hamburguesa: 4.00 minutos
# Pizza: 8.00 minutos
# Spaghetti: 6.00 minutos

# %% [markdown]
# 3) ¿Cuántos clientes completaron su comida

# %%
terminaron = df_eventos[df_eventos['evento'] == 'TERMINO COMIDA']['id'].nunique()
total_clientes = len(df_clientes)

porcentaje_terminaron = (terminaron / total_clientes) * 100


print(f"Clientes que completaron su comida: {terminaron} ({porcentaje_terminaron:.1f}%)")
print(f"Total de clientes: {total_clientes}")


tolerancia_terminaron = df_clientes[df_clientes['id'].isin(
    df_eventos[df_eventos['evento'] == 'TERMINO COMIDA']['id'])]['tolerancia_espera_chef'].mean()


print(f"\nTolerancia promedio de quienes terminaron: {tolerancia_terminaron:.2f} minutos")
# Out:
# Clientes que completaron su comida: 63 (59.4%)
# Total de clientes: 106
#
# Tolerancia promedio de quienes terminaron: 10.95 minutos

# %% [markdown]
# 4) ¿En promedio, desde que llegó hasta que se fue, cuánto tiempo invirtió cada cliente en el restaurante?

# %%
tiempos = []

for id in df_eventos['id'].unique():
    eventos = df_eventos[df_eventos['id'] == id]
    
    if 'LLEGO' in eventos['evento'].values:
        inicio = eventos[eventos['evento'] == 'LLEGO']['time'].values[0]
        
        for fin_evento in ['TERMINO COMIDA', 'SE FUE POR CHEF', 'SIN SILLA']:
            if fin_evento in eventos['evento'].values:
                fin = eventos[eventos['evento'] == fin_evento]['time'].values[0]
                tiempos.append(fin - inicio)
                break

promedio = sum(tiempos) / len(tiempos) if tiempos else 0
print(f"Tiempo promedio de estancia: {promedio:.2f} minutos")
# Out:
# Tiempo promedio de estancia: 7.77 minutos

# %% [markdown]
# 5) ¿Cuántos clientes no alcanzaron a ser atendidos?

# %%
total_clientes = len(df_clientes)
sin_silla = df_eventos[df_eventos['evento'] == 'SIN SILLA']['id'].nunique()
sin_chef = df_eventos[df_eventos['evento'] == 'SE FUE POR CHEF']['id'].nunique()
total_no_atendidos = sin_silla + sin_chef

print(f"Clientes que no encontraron mesa disponible: {sin_silla} ({sin_silla/total_clientes*100:.2f}%)")
print(f"Total clientes no atendidos completamente: {total_no_atendidos} ({total_no_atendidos/total_clientes*100:.2f}%)")

# Contar clientes que completaron su comida
completaron = df_eventos[df_eventos['evento'] == 'TERMINO COMIDA']['id'].nunique()
print(f"Clientes que completaron su comida: {completaron} ({completaron/total_clientes*100:.2f}%)")
# Out:
# Clientes que no encontraron mesa disponible: 39 (36.79%)
# Total clientes no atendidos completamente: 39 (36.79%)
# Clientes que completaron su comida: 63 (59.43%)
